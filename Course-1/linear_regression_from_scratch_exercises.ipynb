# %% [markdown]
# # Introduction to Artificial Intelligence — Linear Regression from Scratch
#
# **Objective.**
# In this notebook, you will implement linear regression manually using only `numpy` and `matplotlib`.
#
# You are **not allowed** to use optimization functions from `scikit-learn`, `torch`, `tensorflow`, or `scipy.optimize`.
#
# The learning loop is:
#
# \[
# \text{prediction} \rightarrow \text{error} \rightarrow \text{gradient} \rightarrow \text{parameter update}
# \]

# %% [markdown]
# ## Preamble — Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## Synthetic Data — Linear Regression with One Feature
#
# We generate synthetic data from:
#
# \[
# y = ax + b + \epsilon
# \]
#
# where \(\epsilon\) is random noise.

# %%
# True parameters
a_true = 3.0
b_true = 5.0

# Synthetic input data
n_samples = 100
x = np.linspace(0, 10, n_samples)

# Noise
noise = np.random.normal(loc=0.0, scale=2.0, size=n_samples)

# Target
y = a_true * x + b_true + noise

plt.figure(figsize=(7, 4))
plt.scatter(x, y, label="Synthetic data")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Synthetic data: y = ax + b + noise")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Exercise 1 — Implement a Linear Regression Model from Scratch
#
# Implement a class named `LinearModel`.
#
# The class must contain at least:
#
# 1. `__init__`
#    - initialize the parameters `w`, `b`,
#    - initialize the learning rate `lr`,
#    - initialize the number of epochs `epochs`,
#    - initialize lists to store the training history.
#
# 2. `forward`
#    - compute predictions:
#    \[
#    \hat{y} = wx + b
#    \]
#
# 3. `calculate_error`
#    - compute the error between `y` and `pred`.
#    - You can use Mean Squared Error:
#    \[
#    MSE = \frac{1}{N}\sum_{i=1}^{N}(y_i-\hat{y}_i)^2
#    \]
#
# 4. `calculate_gradient`
#    - compute the gradients of the error with respect to `w` and `b`.
#
# 5. `update_weight`
#    - update `w` and `b` using gradient descent:
#    \[
#    w \leftarrow w - lr \cdot \frac{\partial L}{\partial w}
#    \]
#    \[
#    b \leftarrow b - lr \cdot \frac{\partial L}{\partial b}
#    \]
#
# 6. `_plots`
#    - display the evolution of the error and gradients across epochs.
#
# 7. `fit`
#    - train the model for the required number of epochs.
#
# Any additional helper function is welcome.

# %%
class LinearModel:
    def __init__(self, w=0.0, b=0.0, lr=0.01, epochs=100):
        """
        Parameters
        ----------
        w : float
            Initial slope.
        b : float
            Initial intercept.
        lr : float
            Learning rate.
        epochs : int
            Number of training iterations.
        """
        # TODO: initialize parameters
        self.w = None
        self.b = None
        self.lr = None
        self.epochs = None

        # TODO: initialize history containers
        self.errors = []
        self.grad_w_history = []
        self.grad_b_history = []

    def forward(self, x):
        """
        Compute model predictions.

        y_pred = w * x + b
        """
        # TODO
        pass

    def calculate_error(self, y, pred):
        """
        Compute the Mean Squared Error.

        MSE = mean((y - pred)^2)
        """
        # TODO
        pass

    def calculate_gradient(self, x, y, pred):
        """
        Compute gradients of the MSE loss.

        dL/dw = (-2/N) * sum(x * (y - pred))
        dL/db = (-2/N) * sum(y - pred)
        """
        # TODO
        pass

    def update_weight(self, grad_w, grad_b):
        """
        Update parameters using gradient descent.
        """
        # TODO
        pass

    def fit(self, x, y):
        """
        Training loop.
        """
        for epoch in range(self.epochs):
            # TODO:
            # 1. compute predictions
            # 2. compute error
            # 3. compute gradients
            # 4. update parameters
            # 5. store error and gradients
            pass

    def _plots(self):
        """
        Plot the evolution of:
        - training error,
        - gradient with respect to w,
        - gradient with respect to b.
        """
        # TODO
        pass

# %% [markdown]
# # Exercise 2 — Train the Model and Analyze the Learning Process
#
# Train your `LinearModel` on the synthetic data and analyze:
#
# - initialization,
# - number of epochs,
# - learning rate.
#
# ## Question 1 — Train the model
#
# Train the model with:
#
# - `w = 0`,
# - `b = 0`,
# - `lr = 0.01`,
# - `epochs = 1000`.
#
# Then display:
#
# - the final values of `w` and `b`,
# - the final training error,
# - the learned regression line.

# %%
# TODO: instantiate and train the model
model = None

# TODO: print learned parameters and final error

# TODO: plot data and learned regression line

# %% [markdown]
# ## Answer — Question 1
#
# - What values did the model learn for \(w\) and \(b\)?
# - Are they close to the true values \(a=3\) and \(b=5\)?
# - Is the fitted line visually reasonable?
#
# **Your answer:**
#
# ...

# %% [markdown]
# ## Question 2 — Role of Initialization
#
# Train several models with different initial values:
#
# - `w = 0`, `b = 0`
# - `w = 10`, `b = 10`
# - `w = -10`, `b = -10`
# - random initialization
#
# Analyze:
#
# 1. Does the final error depend on initialization?
# 2. Does the training time depend on initialization?
# 3. Do all models converge toward similar parameters?

# %%
initializations = [
    (0.0, 0.0),
    (10.0, 10.0),
    (-10.0, -10.0),
    (np.random.randn(), np.random.randn())
]

results = []

for w0, b0 in initializations:
    # TODO: train a model for each initialization
    pass

# TODO: display results

# %% [markdown]
# ## Answer — Question 2
#
# - Does initialization change the final solution?
# - Does initialization change the convergence speed?
# - Why is this problem easier than many deep learning problems?
#
# **Your answer:**
#
# ...

# %% [markdown]
# ## Question 3 — Role of the Number of Epochs
#
# Train the model with different numbers of epochs:
#
# - 10
# - 50
# - 100
# - 500
# - 1000
#
# Analyze:
#
# 1. What happens when the number of epochs is too small?
# 2. What happens when it is very large?
# 3. Which limitation discussed in the course is related to this parameter?
#
# Hint: think about **computational cost** and **convergence**.

# %%
epoch_values = [10, 50, 100, 500, 1000]

for ep in epoch_values:
    # TODO: train model
    pass

# %% [markdown]
# ## Answer — Question 3
#
# - How many epochs are needed to obtain a good model?
# - Does increasing epochs always improve the result?
# - What is the computational trade-off?
#
# **Your answer:**
#
# ...

# %% [markdown]
# ## Question 4 — Role of the Learning Rate
#
# Train the model with different learning rates:
#
# - `lr = 0.0001`
# - `lr = 0.001`
# - `lr = 0.01`
# - `lr = 0.1`
# - `lr = 1.0`
#
# Analyze:
#
# 1. What happens when the learning rate is too small?
# 2. What happens when the learning rate is too large?
# 3. Why is the learning rate one of the most important hyperparameters?

# %%
learning_rates = [0.0001, 0.001, 0.01, 0.1, 1.0]

for lr in learning_rates:
    # TODO: train model
    pass

# %% [markdown]
# ## Answer — Question 4
#
# - Which learning rate worked best?
# - Did some learning rates fail?
# - How do the gradients behave when the learning rate is too large?
#
# **Your answer:**
#
# ...

# %% [markdown]
# # Exercise 3 — Linear Regression with Two Features
#
# We now generate synthetic data with two input features:
#
# \[
# y = a_1x_1 + a_2x_2 + b + \epsilon
# \]
#
# You must reimplement the model to support two features.
#
# The prediction becomes:
#
# \[
# \hat{y} = w_1x_1 + w_2x_2 + b
# \]
#
# or, in vector form:
#
# \[
# \hat{y} = Xw + b
# \]

# %%
np.random.seed(42)

n_samples = 200

x1 = np.random.uniform(0, 10, n_samples)
x2 = np.random.uniform(-5, 5, n_samples)

a1_true = 2.0
a2_true = -4.0
b_true_2d = 3.0

noise = np.random.normal(0, 1.5, n_samples)

y_2d = a1_true * x1 + a2_true * x2 + b_true_2d + noise
X_2d = np.column_stack([x1, x2])

print("X shape:", X_2d.shape)
print("y shape:", y_2d.shape)

# %% [markdown]
# ## Task
#
# Reimplement a class named `LinearModel2D`.
#
# Expected methods:
#
# - `__init__`
# - `forward`
# - `calculate_error`
# - `calculate_gradient`
# - `update_weight`
# - `fit`
# - `_plots`
#
# The model must learn:
#
# \[
# w_1, w_2, b
# \]

# %%
class LinearModel2D:
    def __init__(self, w=None, b=0.0, lr=0.01, epochs=100):
        if w is None:
            w = np.zeros(2)

        self.w = None
        self.b = None
        self.lr = None
        self.epochs = None

        self.errors = []
        self.grad_w_history = []
        self.grad_b_history = []

    def forward(self, X):
        """
        Compute predictions:
            pred = X @ w + b
        """
        # TODO
        pass

    def calculate_error(self, y, pred):
        """
        Compute MSE.
        """
        # TODO
        pass

    def calculate_gradient(self, X, y, pred):
        """
        Compute gradients.

        dL/dw = (-2/N) * X.T @ (y - pred)
        dL/db = (-2/N) * sum(y - pred)
        """
        # TODO
        pass

    def update_weight(self, grad_w, grad_b):
        """
        Update w and b.
        """
        # TODO
        pass

    def fit(self, X, y):
        """
        Training loop.
        """
        for epoch in range(self.epochs):
            # TODO
            pass

    def _plots(self):
        """
        Plot error and gradient norms.
        """
        # TODO
        pass

# %%
# TODO: train LinearModel2D on X_2d and y_2d

model_2d = None

# TODO: display learned parameters

# %% [markdown]
# ## Answer — Exercise 3
#
# - Are the learned parameters close to the true values?
# - What changes compared to the one-feature case?
# - Why is the vector notation useful?
#
# **Your answer:**
#
# ...

# %% [markdown]
# # Exercise 4 — Feature Scale Problem
#
# We now create a new dataset with two features of very different scales:
#
# - \(x_1 \in [0, 1]\)
# - \(x_2 \in [0, 100]\)
#
# The goal is to observe that gradient descent can become difficult when input features do not have comparable scales.

# %%
np.random.seed(42)

n_samples = 200

x1_small = np.random.uniform(0, 1, n_samples)
x2_large = np.random.uniform(0, 100, n_samples)

a1_true_scaled = 5.0
a2_true_scaled = 0.5
b_true_scaled = 2.0

noise = np.random.normal(0, 1.0, n_samples)

y_scaled = (
    a1_true_scaled * x1_small
    + a2_true_scaled * x2_large
    + b_true_scaled
    + noise
)

X_scaled = np.column_stack([x1_small, x2_large])

print("Feature 1 range:", X_scaled[:, 0].min(), X_scaled[:, 0].max())
print("Feature 2 range:", X_scaled[:, 1].min(), X_scaled[:, 1].max())

# %% [markdown]
# ## Question 1 — Train Without Normalization
#
# Train your `LinearModel2D` on this dataset.
#
# Use several learning rates and observe what happens.
#
# Questions:
#
# 1. Does the regression work as well as before?
# 2. Which parameter receives the largest gradient?
# 3. Why can a large-scale feature dominate the optimization?
# 4. What happens when the learning rate is increased?

# %%
# TODO: train without normalization

model_scaled = None

# TODO: inspect gradient histories and learned parameters

# %% [markdown]
# ## Answer — Question 1
#
# - Does the model converge?
# - Are gradients for both features comparable?
# - Why does feature scale matter?
#
# **Your answer:**
#
# ...

# %% [markdown]
# ## Question 2 — Analyze the Input Features and Gradients
#
# Plot:
#
# 1. the distribution of each feature,
# 2. the gradient magnitude for each weight during training.
#
# Explain why the feature with values in \([0,100]\) can produce much larger gradients.

# %%
plt.figure(figsize=(7, 4))
plt.hist(X_scaled[:, 0], bins=20, alpha=0.7, label="x1: [0, 1]")
plt.hist(X_scaled[:, 1], bins=20, alpha=0.7, label="x2: [0, 100]")
plt.xlabel("Feature value")
plt.ylabel("Frequency")
plt.title("Feature distributions")
plt.legend()
plt.grid(True)
plt.show()

# TODO: plot gradient magnitudes for each weight

# %% [markdown]
# ## Answer — Question 2
#
# - Which feature has the largest scale?
# - Which gradient is larger?
# - How does this affect optimization?
#
# **Your answer:**
#
# ...

# %% [markdown]
# ## Question 3 — How to Solve the Problem?
#
# A common solution is to normalize or standardize the input features.
#
# For example, standardization:
#
# \[
# x' = \frac{x - \mu}{\sigma}
# \]
#
# where:
#
# - \(\mu\) is the mean,
# - \(\sigma\) is the standard deviation.
#
# Implement feature standardization and train the model again.

# %%
# TODO: standardize the features

X_scaled_standardized = None

# Example:
# mean = X_scaled.mean(axis=0)
# std = X_scaled.std(axis=0)
# X_scaled_standardized = (X_scaled - mean) / std

# TODO: train LinearModel2D again on standardized features
model_standardized = None

# TODO: compare convergence before and after standardization

# %% [markdown]
# ## Answer — Question 3
#
# - Does standardization improve convergence?
# - Are the gradients more balanced?
# - Why is feature scaling important before training many machine learning models?
#
# **Your answer:**
#
# ...

# %% [markdown]
# # References
#
# This notebook follows standard presentations of linear regression, mean squared error, gradient descent, and feature scaling commonly found in introductory machine learning textbooks:
#
# - Christopher M. Bishop, *Pattern Recognition and Machine Learning*, 2006.
# - Kevin P. Murphy, *Machine Learning: A Probabilistic Perspective*, 2012.
# - Ian Goodfellow, Yoshua Bengio, Aaron Courville, *Deep Learning*, 2016.
